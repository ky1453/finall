# %% [markdown]
# > İLERİ PROGRAMLAMA DERSİ FİNAL ÖDEVİ
#
# ÖZNUR KAYA
#
# 23040201006
#
# > Dersin Hocası: Dr. Öğretim Üyesi Gökalp TULUM
# >
# > SORU 4 -CEVAP
# >
# > histogram = {
# > 100: 12, 101: 18, 102: 32, 103: 48, 104: 52, 105: 65, 106: 55, 107:
# > 42, 108: 32, 109: 16, 110: 10,
# > 140: 5, 141: 18, 142: 25, 143: 32, 144: 40, 145: 65, 146: 43, 147: 32,
# > 148: 20, 149: 10, 150: 4
# > }
# > histogram = {
# > 100: 12, 101: 18, 102: 32, 103: 48, 104: 52, 105: 65, 106: 55, 107:
# > 42, 108: 32, 109: 16, 110: 10,
# > 140: 5, 141: 18, 142: 25, 143: 32, 144: 40, 145: 65, 146: 43, 147: 32,
# > 148: 20, 149: 10, 150: 4
# > }
# >
# > def compute_mean(group):
# > total_intensity = sum(value \* count for value, count in group)
# > total_count = sum(count for \_, count in group)
# > return total_intensity / total_count if total_count != 0 else 0
# >
# > def find_optimum_threshold(histogram, initial_threshold=100,
# > threshold_diff=1):
# > T0 = initial_threshold
# > while True:
# > G1 = \[(value, count) for value, count in histogram.items() if value
# > \> T0\]
# >
# > G2 = \[(value, count) for value, count in histogram.items() if value
# > \<= T0\]
# >
# > m1 = compute_mean(G1)
# > m2 = compute_mean(G2)
# >
# > T1 = (m1 + m2) / 2
# >
# > if abs(T1 - T0) \< threshold_diff:
# > break
# >
# > T0 = T1
# >
# > return T1
# >
# > optimum_threshold = find_optimum_threshold(histogram)
# > optimum_threshold
# > import numpy as np
# >
# > histogram = {
# > 100: 12, 101: 18, 102: 32, 103: 48, 104: 52, 105: 65, 106: 55, 107:
# > 42, 108: 32, 109: 16, 110: 10,
# > 140: 5, 141: 18, 142: 25, 143: 32, 144: 40, 145: 65, 146: 43, 147: 32,
# > 148: 20, 149: 10, 150: 4
# > }
# >
# > def compute_mean(group):
# > total_intensity = sum(value \* count for value, count in group)
# > total_count = sum(count for \_, count in group)
# > return total_intensity / total_count if total_count != 0 else 0
# >
# > def find_optimum_threshold(histogram, initial_threshold=100,
# > threshold_diff=1):
# > T0 = initial_threshold
# > while True:
# > G1 = \[(value, count) for value, count in histogram.items() if value
# > \> T0\] G2 = \[(value, count) for value, count in histogram.items() if
# > value \<= T0\]
# >
# > m1 = compute_mean(G1)
# > m2 = compute_mean(G2)
# > T1 = (m1 + m2) / 2
# > if abs(T1 - T0) \< threshold_diff:
# > break
# > T0 = T1
# > return T1
# >
# > optimum_threshold = find_optimum_threshold(histogram)
# > print(optimum_threshold)
# > 124.88132635253055
